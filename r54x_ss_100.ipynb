# %%
from pyspark import SparkContext, SparkConf
import random
import math
import time
import matplotlib.pyplot as plt
import psutil

def is_point_inside_unit_circle(p):
    x, y = random.random(), random.random()
    return x*x + y*y <= 1

if __name__ == "__main__":
    # Stop any existing SparkContext
    try:
        sc.stop()
    except:
        pass

    # Initialize Spark Context with increased resources
    conf = SparkConf().setAppName("MonteCarloSimulation").set("spark.executor.memory", "4g").set("spark.executor.cores", "2")
    sc = SparkContext(conf=conf)

    # List of different numbers of samples
    sample_sizes = [10,1020,2030,3040,4050,5060,6070,7080,8090,9100,10110,11120,12130,13140,14150,15160,16170,17180,18190,19200,20210,21220,22230,23240,24250,25260,26270,27280,28290,29300,30310,31320,32330,33340,34350,35360,36370,37380,38390,39400,40410,41420,42430,43440,44450,45460,46470,47480,48490,49500,50510,51520,52530,53540,54550,55560,56570,57580,58590,59600,60610,61620,62630,63640,64650,65660,66670,67680,68690,69700,70710,71720,72730,73740,74750,75760,76770,77780,78790,79800,80810,81820,82830,83840,84850,85860,86870,87880,88890,89900,90910,91920,92930,93940,94950,95960,96970,97980,98990,100000]

    # Lists to store results
    pi_estimates = []
    absolute_errors = []
    durations = []
    ram_usage = []
    cpu_usage = []
    print("========PYSPARK========")
    # Iterate over different sample sizes
    for num_samples in sample_sizes:
        # Start timing
        start_time = time.time()

        # Distribute the samples across the cluster
        samples = sc.parallelize(range(0, num_samples))

        # Perform the Monte Carlo simulation
        count = samples.filter(is_point_inside_unit_circle).count()

        # Estimate Pi
        pi_estimate = 4 * count / num_samples
        pi_estimates.append(pi_estimate)

        # Known value of Pi
        true_pi = math.pi

        # Calculate the absolute error
        absolute_error = abs(pi_estimate - true_pi)
        absolute_errors.append(absolute_error)

        # End timing
        end_time = time.time()

        # Calculate the time taken
        duration = end_time - start_time
        durations.append(duration)

        # Retrieve system's RAM and CPU usage
        ram_percent = psutil.virtual_memory().percent
        cpu_percent = psutil.cpu_percent()

        ram_usage.append(ram_percent)
        cpu_usage.append(cpu_percent)

        # Print the result, the accuracy, and the time taken
        print(f"Number of samples: {num_samples}")
        print(f"Estimated value of Pi is {pi_estimate}")
        print(f"Absolute error is {absolute_error}")
        print(f"Time taken is {duration} seconds")
        print(f"RAM usage: {ram_percent:.2f}%")
        print(f"CPU usage: {cpu_percent:.2f}%")
        print("\n")

    # Stop the Spark Context
    sc.stop()

    # Plotting results
    plt.figure(figsize=(18, 9))

    # Plot 1: Estimated Pi vs Sample Size
    plt.subplot(2, 2, 1)
    plt.plot(sample_sizes, pi_estimates, marker='o', linestyle='-', color='b', label='Estimated Pi')
    plt.axhline(y=math.pi, color='r', linestyle='--', label='True Pi')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Estimated Pi')
    plt.title('Estimated Pi vs Sample Size')
    plt.legend()

    # Plot 2: Absolute Error vs Sample Size
    plt.subplot(2, 2, 2)
    plt.plot(sample_sizes, absolute_errors, marker='o', linestyle='-', color='g',label='Absolute Error')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Absolute Error')
    plt.title('Absolute Error vs Sample Size')
    plt.legend()

    # Plot 3: Time Taken vs Sample Size
    plt.subplot(2, 2, 3)
    plt.plot(sample_sizes, durations, marker='o', linestyle='-', color='m',label='Time Taken (seconds)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Time Taken (seconds)')
    plt.title('Time Taken vs Sample Size')
    plt.legend()

    # Plot 4: Resource Usage
    plt.subplot(2, 2, 4)
    plt.plot(sample_sizes, ram_usage, marker='o', linestyle='-', color='b', label='RAM Usage (%)')
    plt.plot(sample_sizes, cpu_usage, marker='o', linestyle='-', color='g', label='CPU Usage (%)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Resource Usage (%)')
    plt.title('Resource Usage vs Sample Size')
    plt.legend()

    # Adjust layout and display the plots
    plt.tight_layout()
    plt.show()
# Out:
# ========PYSPARK========
# Number of samples: 10
# Estimated value of Pi is 2.4
# Absolute error is 0.7415926535897932
# Time taken is 1.5637080669403076 seconds
# RAM usage: 2.10%
# CPU usage: 12.80%
#
#
# Number of samples: 1020
# Estimated value of Pi is 3.1372549019607843
# Absolute error is 0.004337751629008846
# Time taken is 0.2904646396636963 seconds
# RAM usage: 2.10%
# CPU usage: 74.40%
#
#
# Number of samples: 2030
# Estimated value of Pi is 3.1724137931034484
# Absolute error is 0.030821139513655282
# Time taken is 0.3165724277496338 seconds
# RAM usage: 2.20%
# CPU usage: 80.50%
#
#
# Number of samples: 3040
# Estimated value of Pi is 3.161842105263158
# Absolute error is 0.02024945167336467
# Time taken is 0.28986406326293945 seconds
# RAM usage: 2.20%
# CPU usage: 83.00%
#
#
# Number of samples: 4050
# Estimated value of Pi is 3.15358024691358
# Absolute error is 0.01198759332378696
# Time taken is 0.2971632480621338 seconds
# RAM usage: 2.30%
# CPU usage: 79.80%
#
#
# Number of samples: 5060
# Estimated value of Pi is 3.148616600790514
# Absolute error is 0.007023947200720748
# Time taken is 0.3176271915435791 seconds
# RAM usage: 2.30%
# CPU usage: 76.50%
#
#
# Number of samples: 6070
# Estimated value of Pi is 3.1070840197693577
# Absolute error is 0.03450863382043545
# Time taken is 0.2216634750366211 seconds
# RAM usage: 2.30%
# CPU usage: 86.40%
#
#
# Number of samples: 7080
# Estimated value of Pi is 3.136723163841808
# Absolute error is 0.004869489747985067
# Time taken is 0.26750683784484863 seconds
# RAM usage: 2.30%
# CPU usage: 76.10%
#
#
# Number of samples: 8090
# Estimated value of Pi is 3.150061804697157
# Absolute error is 0.008469151107363793
# Time taken is 0.23840808868408203 seconds
# RAM usage: 2.30%
# CPU usage: 78.20%
#
#
# Number of samples: 9100
# Estimated value of Pi is 3.128791208791209
# Absolute error is 0.01280144479858425
# Time taken is 0.20881009101867676 seconds
# RAM usage: 2.30%
# CPU usage: 85.40%
#
#
# Number of samples: 10110
# Estimated value of Pi is 3.147774480712166
# Absolute error is 0.006181827122373029
# Time taken is 0.24596381187438965 seconds
# RAM usage: 2.40%
# CPU usage: 75.80%
#
#
# Number of samples: 11120
# Estimated value of Pi is 3.121223021582734
# Absolute error is 0.020369632007059213
# Time taken is 0.2162027359008789 seconds
# RAM usage: 2.40%
# CPU usage: 85.50%
#
#
# Number of samples: 12130
# Estimated value of Pi is 3.1343775762572137
# Absolute error is 0.007215077332579423
# Time taken is 0.21585631370544434 seconds
# RAM usage: 2.40%
# CPU usage: 87.50%
#
#
# Number of samples: 13140
# Estimated value of Pi is 3.1190258751902586
# Absolute error is 0.02256677839953447
# Time taken is 0.20767474174499512 seconds
# RAM usage: 2.40%
# CPU usage: 85.60%
#
#
# Number of samples: 14150
# Estimated value of Pi is 3.1426148409893995
# Absolute error is 0.0010221873996063557
# Time taken is 0.19817328453063965 seconds
# RAM usage: 2.40%
# CPU usage: 88.40%
#
#
# Number of samples: 15160
# Estimated value of Pi is 3.1350923482849606
# Absolute error is 0.006500305304832477
# Time taken is 0.20982575416564941 seconds
# RAM usage: 2.40%
# CPU usage: 85.90%
#
#
# Number of samples: 16170
# Estimated value of Pi is 3.140630797773655
# Absolute error is 0.0009618558161381685
# Time taken is 0.22322320938110352 seconds
# RAM usage: 2.40%
# CPU usage: 81.60%
#
#
# Number of samples: 17180
# Estimated value of Pi is 3.1534342258440047
# Absolute error is 0.011841572254211563
# Time taken is 0.19412994384765625 seconds
# RAM usage: 2.40%
# CPU usage: 90.70%
#
#
# Number of samples: 18190
# Estimated value of Pi is 3.1459043430456295
# Absolute error is 0.004311689455836376
# Time taken is 0.20706605911254883 seconds
# RAM usage: 2.40%
# CPU usage: 88.10%
#
#
# Number of samples: 19200
# Estimated value of Pi is 3.1233333333333335
# Absolute error is 0.0182593202564596
# Time taken is 0.21669960021972656 seconds
# RAM usage: 2.40%
# CPU usage: 82.10%
#
#
# Number of samples: 20210
# Estimated value of Pi is 3.1451756556160317
# Absolute error is 0.003583002026238624
# Time taken is 0.19501137733459473 seconds
# RAM usage: 2.40%
# CPU usage: 88.80%
#
#
# Number of samples: 21220
# Estimated value of Pi is 3.144015080113101
# Absolute error is 0.00242242652330793
# Time taken is 0.19525861740112305 seconds
# RAM usage: 2.40%
# CPU usage: 88.70%
#
#
# Number of samples: 22230
# Estimated value of Pi is 3.1469185784975258
# Absolute error is 0.005325924907732649
# Time taken is 0.2072765827178955 seconds
# RAM usage: 2.40%
# CPU usage: 87.70%
#
#
# Number of samples: 23240
# Estimated value of Pi is 3.1476764199655767
# Absolute error is 0.006083766375783561
# Time taken is 0.25925779342651367 seconds
# RAM usage: 2.40%
# CPU usage: 74.60%
#
#
# Number of samples: 24250
# Estimated value of Pi is 3.144412371134021
# Absolute error is 0.002819717544227718
# Time taken is 0.2064046859741211 seconds
# RAM usage: 2.40%
# CPU usage: 89.70%
#
#
# Number of samples: 25260
# Estimated value of Pi is 3.133808392715756
# Absolute error is 0.007784260874037052
# Time taken is 0.19655156135559082 seconds
# RAM usage: 2.40%
# CPU usage: 91.40%
#
#
# Number of samples: 26270
# Estimated value of Pi is 3.1470118005329275
# Absolute error is 0.00541914694313439
# Time taken is 0.19949007034301758 seconds
# RAM usage: 2.40%
# CPU usage: 89.70%
#
#
# Number of samples: 27280
# Estimated value of Pi is 3.1516129032258067
# Absolute error is 0.010020249636013556
# Time taken is 0.20016860961914062 seconds
# RAM usage: 2.40%
# CPU usage: 90.60%
#
#
# Number of samples: 28290
# Estimated value of Pi is 3.139625309296571
# Absolute error is 0.0019673442932219842
# Time taken is 0.23005151748657227 seconds
# RAM usage: 2.40%
# CPU usage: 79.70%
#
#
# Number of samples: 29300
# Estimated value of Pi is 3.142935153583618
# Absolute error is 0.0013424999938247417
# Time taken is 0.22713780403137207 seconds
# RAM usage: 2.40%
# CPU usage: 78.60%
#
#
# Number of samples: 30310
# Estimated value of Pi is 3.1427251732101618
# Absolute error is 0.0011325196203686438
# Time taken is 0.20007634162902832 seconds
# RAM usage: 2.40%
# CPU usage: 89.40%
#
#
# Number of samples: 31320
# Estimated value of Pi is 3.1454661558109835
# Absolute error is 0.003873502221190428
# Time taken is 0.19683551788330078 seconds
# RAM usage: 2.40%
# CPU usage: 90.20%
#
#
# Number of samples: 32330
# Estimated value of Pi is 3.1516238787503865
# Absolute error is 0.010031225160593404
# Time taken is 0.19920730590820312 seconds
# RAM usage: 2.40%
# CPU usage: 90.30%
#
#
# Number of samples: 33340
# Estimated value of Pi is 3.1410917816436714
# Absolute error is 0.0005008719461216948
# Time taken is 0.19838476181030273 seconds
# RAM usage: 2.40%
# CPU usage: 89.60%
#
#
# Number of samples: 34350
# Estimated value of Pi is 3.1500436681222705
# Absolute error is 0.00845101453247743
# Time taken is 0.1867823600769043 seconds
# RAM usage: 2.40%
# CPU usage: 91.60%
#
#
# Number of samples: 35360
# Estimated value of Pi is 3.1392533936651583
# Absolute error is 0.0023392599246347956
# Time taken is 0.19787025451660156 seconds
# RAM usage: 2.40%
# CPU usage: 92.10%
#
#
# Number of samples: 36370
# Estimated value of Pi is 3.143909815782238
# Absolute error is 0.0023171621924449326
# Time taken is 0.21094536781311035 seconds
# RAM usage: 2.40%
# CPU usage: 88.20%
#
#
# Number of samples: 37380
# Estimated value of Pi is 3.1349384697699305
# Absolute error is 0.006654183819862602
# Time taken is 0.23996353149414062 seconds
# RAM usage: 2.40%
# CPU usage: 77.80%
#
#
# Number of samples: 38390
# Estimated value of Pi is 3.1228965876530346
# Absolute error is 0.018696065936758544
# Time taken is 0.22168684005737305 seconds
# RAM usage: 2.50%
# CPU usage: 83.40%
#
#
# Number of samples: 39400
# Estimated value of Pi is 3.1243654822335025
# Absolute error is 0.017227171356290594
# Time taken is 0.2453467845916748 seconds
# RAM usage: 2.50%
# CPU usage: 79.10%
#
#
# Number of samples: 40410
# Estimated value of Pi is 3.1519920811680278
# Absolute error is 0.010399427578234643
# Time taken is 0.21608424186706543 seconds
# RAM usage: 2.50%
# CPU usage: 85.30%
#
#
# Number of samples: 41420
# Estimated value of Pi is 3.137518107194592
# Absolute error is 0.004074546395201217
# Time taken is 0.22069478034973145 seconds
# RAM usage: 2.50%
# CPU usage: 81.90%
#
#
# Number of samples: 42430
# Estimated value of Pi is 3.1356115955691726
# Absolute error is 0.005981058020620544
# Time taken is 0.19731688499450684 seconds
# RAM usage: 2.50%
# CPU usage: 90.20%
#
#
# Number of samples: 43440
# Estimated value of Pi is 3.1531307550644567
# Absolute error is 0.011538101474663609
# Time taken is 0.20688438415527344 seconds
# RAM usage: 2.50%
# CPU usage: 86.60%
#
#
# Number of samples: 44450
# Estimated value of Pi is 3.1476265466816646
# Absolute error is 0.006033893091871523
# Time taken is 0.20465302467346191 seconds
# RAM usage: 2.60%
# CPU usage: 88.70%
#
#
# Number of samples: 45460
# Estimated value of Pi is 3.1329520457545095
# Absolute error is 0.008640607835283642
# Time taken is 0.19414997100830078 seconds
# RAM usage: 2.60%
# CPU usage: 89.70%
#
#
# Number of samples: 46470
# Estimated value of Pi is 3.143275231332042
# Absolute error is 0.001682577742248892
# Time taken is 0.19305706024169922 seconds
# RAM usage: 2.60%
# CPU usage: 90.60%
#
#
# Number of samples: 47480
# Estimated value of Pi is 3.142207245155855
# Absolute error is 0.0006145915660620282
# Time taken is 0.1966242790222168 seconds
# RAM usage: 2.60%
# CPU usage: 90.20%
#
#
# Number of samples: 48490
# Estimated value of Pi is 3.141596205403176
# Absolute error is 3.551813382962621e-06
# Time taken is 0.203902006149292 seconds
# RAM usage: 2.60%
# CPU usage: 88.40%
#
#
# Number of samples: 49500
# Estimated value of Pi is 3.1347070707070706
# Absolute error is 0.006885582882722563
# Time taken is 0.209855318069458 seconds
# RAM usage: 2.60%
# CPU usage: 85.30%
#
#
# Number of samples: 50510
# Estimated value of Pi is 3.141160166303702
# Absolute error is 0.00043248728609102116
# Time taken is 0.25407981872558594 seconds
# RAM usage: 2.60%
# CPU usage: 74.60%
#
#
# Number of samples: 51520
# Estimated value of Pi is 3.1411490683229815
# Absolute error is 0.00044358526681165245
# Time taken is 0.19447851181030273 seconds
# RAM usage: 2.60%
# CPU usage: 90.00%
#
#
# Number of samples: 52530
# Estimated value of Pi is 3.145631067961165
# Absolute error is 0.004038414371371868
# Time taken is 0.2312614917755127 seconds
# RAM usage: 2.60%
# CPU usage: 82.40%
#
#
# Number of samples: 53540
# Estimated value of Pi is 3.1545760179305193
# Absolute error is 0.012983364340726222
# Time taken is 0.21614432334899902 seconds
# RAM usage: 2.60%
# CPU usage: 83.90%
#
#
# Number of samples: 54550
# Estimated value of Pi is 3.1498441796516956
# Absolute error is 0.008251526061902492
# Time taken is 0.20238208770751953 seconds
# RAM usage: 2.60%
# CPU usage: 89.80%
#
#
# Number of samples: 55560
# Estimated value of Pi is 3.134989200863931
# Absolute error is 0.006603452725862269
# Time taken is 0.22533154487609863 seconds
# RAM usage: 2.60%
# CPU usage: 83.90%
#
#
# Number of samples: 56570
# Estimated value of Pi is 3.132331624535973
# Absolute error is 0.009261029053820202
# Time taken is 0.24533438682556152 seconds
# RAM usage: 2.60%
# CPU usage: 77.60%
#
#
# Number of samples: 57580
# Estimated value of Pi is 3.143035776311219
# Absolute error is 0.0014431227214259934
# Time taken is 0.22056269645690918 seconds
# RAM usage: 2.60%
# CPU usage: 82.10%
#
#
# Number of samples: 58590
# Estimated value of Pi is 3.1384195255162997
# Absolute error is 0.0031731280734934586
# Time taken is 0.18799495697021484 seconds
# RAM usage: 2.60%
# CPU usage: 91.10%
#
#
# Number of samples: 59600
# Estimated value of Pi is 3.1436241610738254
# Absolute error is 0.0020315074840322467
# Time taken is 0.1998443603515625 seconds
# RAM usage: 2.60%
# CPU usage: 91.20%
#
#
# Number of samples: 60610
# Estimated value of Pi is 3.1416597921135128
# Absolute error is 6.713852371964535e-05
# Time taken is 0.19896531105041504 seconds
# RAM usage: 2.60%
# CPU usage: 90.00%
#
#
# Number of samples: 61620
# Estimated value of Pi is 3.147160012982798
# Absolute error is 0.005567359393004789
# Time taken is 0.19327926635742188 seconds
# RAM usage: 2.60%
# CPU usage: 91.90%
#
#
# Number of samples: 62630
# Estimated value of Pi is 3.1372824524988023
# Absolute error is 0.004310201090990784
# Time taken is 0.19000506401062012 seconds
# RAM usage: 2.60%
# CPU usage: 91.70%
#
#
# Number of samples: 63640
# Estimated value of Pi is 3.1336895034569454
# Absolute error is 0.007903150132847703
# Time taken is 0.19317007064819336 seconds
# RAM usage: 2.60%
# CPU usage: 92.20%
#
#
# Number of samples: 64650
# Estimated value of Pi is 3.149327146171694
# Absolute error is 0.0077344925819007315
# Time taken is 0.1941831111907959 seconds
# RAM usage: 2.60%
# CPU usage: 92.30%
#
#
# Number of samples: 65660
# Estimated value of Pi is 3.1516905269570517
# Absolute error is 0.010097873367258536
# Time taken is 0.19690680503845215 seconds
# RAM usage: 2.60%
# CPU usage: 92.40%
#
#
# Number of samples: 66670
# Estimated value of Pi is 3.1399430028498574
# Absolute error is 0.0016496507399357263
# Time taken is 0.2676422595977783 seconds
# RAM usage: 2.60%
# CPU usage: 76.70%
#
#
# Number of samples: 67680
# Estimated value of Pi is 3.1397163120567377
# Absolute error is 0.0018763415330553812
# Time taken is 0.18513202667236328 seconds
# RAM usage: 2.60%
# CPU usage: 91.20%
#
#
# Number of samples: 68690
# Estimated value of Pi is 3.140777405735915
# Absolute error is 0.0008152478538780983
# Time taken is 0.24117064476013184 seconds
# RAM usage: 2.60%
# CPU usage: 81.10%
#
#
# Number of samples: 69700
# Estimated value of Pi is 3.1341176470588237
# Absolute error is 0.007475006530969441
# Time taken is 0.1890854835510254 seconds
# RAM usage: 2.60%
# CPU usage: 91.70%
#
#
# Number of samples: 70710
# Estimated value of Pi is 3.142638947815019
# Absolute error is 0.0010462942252260632
# Time taken is 0.20299577713012695 seconds
# RAM usage: 2.60%
# CPU usage: 90.10%
#
#
# Number of samples: 71720
# Estimated value of Pi is 3.1419966536530954
# Absolute error is 0.0004040000633023233
# Time taken is 0.20032548904418945 seconds
# RAM usage: 2.60%
# CPU usage: 91.00%
#
#
# Number of samples: 72730
# Estimated value of Pi is 3.151931802557404
# Absolute error is 0.01033914896761079
# Time taken is 0.23740077018737793 seconds
# RAM usage: 2.70%
# CPU usage: 81.50%
#
#
# Number of samples: 73740
# Estimated value of Pi is 3.1357743422836997
# Absolute error is 0.005818311306093449
# Time taken is 0.2228412628173828 seconds
# RAM usage: 2.60%
# CPU usage: 82.40%
#
#
# Number of samples: 74750
# Estimated value of Pi is 3.140334448160535
# Absolute error is 0.0012582054292580303
# Time taken is 0.18767499923706055 seconds
# RAM usage: 2.60%
# CPU usage: 91.30%
#
#
# Number of samples: 75760
# Estimated value of Pi is 3.148204857444562
# Absolute error is 0.0066122038547686834
# Time taken is 0.18481683731079102 seconds
# RAM usage: 2.60%
# CPU usage: 92.20%
#
#
# Number of samples: 76770
# Estimated value of Pi is 3.140758108636186
# Absolute error is 0.0008345449536069083
# Time taken is 0.21178746223449707 seconds
# RAM usage: 2.60%
# CPU usage: 91.50%
#
#
# Number of samples: 77780
# Estimated value of Pi is 3.149138596040113
# Absolute error is 0.00754594245031992
# Time taken is 0.20738768577575684 seconds
# RAM usage: 2.60%
# CPU usage: 87.90%
#
#
# Number of samples: 78790
# Estimated value of Pi is 3.1294326691204466
# Absolute error is 0.012159984469346519
# Time taken is 0.1979069709777832 seconds
# RAM usage: 2.60%
# CPU usage: 91.10%
#
#
# Number of samples: 79800
# Estimated value of Pi is 3.1500751879699247
# Absolute error is 0.008482534380131579
# Time taken is 0.1952342987060547 seconds
# RAM usage: 2.60%
# CPU usage: 91.30%
#
#
# Number of samples: 80810
# Estimated value of Pi is 3.133473580002475
# Absolute error is 0.008119073587318226
# Time taken is 0.24653005599975586 seconds
# RAM usage: 2.60%
# CPU usage: 75.80%
#
#
# Number of samples: 81820
# Estimated value of Pi is 3.1434368125152776
# Absolute error is 0.001844158925484507
# Time taken is 0.19607043266296387 seconds
# RAM usage: 2.60%
# CPU usage: 90.80%
#
#
# Number of samples: 82830
# Estimated value of Pi is 3.14514064952312
# Absolute error is 0.003547995933326664
# Time taken is 0.19259905815124512 seconds
# RAM usage: 2.60%
# CPU usage: 91.90%
#
#
# Number of samples: 83840
# Estimated value of Pi is 3.134732824427481
# Absolute error is 0.006859829162312092
# Time taken is 0.19483160972595215 seconds
# RAM usage: 2.60%
# CPU usage: 91.30%
#
#
# Number of samples: 84850
# Estimated value of Pi is 3.1341897466116677
# Absolute error is 0.007402906978125401
# Time taken is 0.2319960594177246 seconds
# RAM usage: 2.60%
# CPU usage: 82.20%
#
#
# Number of samples: 85860
# Estimated value of Pi is 3.1340787328208712
# Absolute error is 0.007513920768921878
# Time taken is 0.19227194786071777 seconds
# RAM usage: 2.60%
# CPU usage: 91.60%
#
#
# Number of samples: 86870
# Estimated value of Pi is 3.136502820306205
# Absolute error is 0.005089833283588252
# Time taken is 0.19433093070983887 seconds
# RAM usage: 2.60%
# CPU usage: 91.00%
#
#
# Number of samples: 87880
# Estimated value of Pi is 3.137960855712335
# Absolute error is 0.003631797877458265
# Time taken is 0.18895626068115234 seconds
# RAM usage: 2.60%
# CPU usage: 92.40%
#
#
# Number of samples: 88890
# Estimated value of Pi is 3.129440881988975
# Absolute error is 0.012151771600818151
# Time taken is 0.20184087753295898 seconds
# RAM usage: 2.60%
# CPU usage: 92.50%
#
#
# Number of samples: 89900
# Estimated value of Pi is 3.137797552836485
# Absolute error is 0.003795100753308134
# Time taken is 0.2645854949951172 seconds
# RAM usage: 2.60%
# CPU usage: 74.20%
#
#
# Number of samples: 90910
# Estimated value of Pi is 3.137828621713783
# Absolute error is 0.0037640318760101543
# Time taken is 0.21046161651611328 seconds
# RAM usage: 2.60%
# CPU usage: 86.40%
#
#
# Number of samples: 91920
# Estimated value of Pi is 3.1412532637075716
# Absolute error is 0.0003393898822214858
# Time taken is 0.21509289741516113 seconds
# RAM usage: 2.60%
# CPU usage: 84.30%
#
#
# Number of samples: 92930
# Estimated value of Pi is 3.1495103841601204
# Absolute error is 0.007917730570327297
# Time taken is 0.19762587547302246 seconds
# RAM usage: 2.60%
# CPU usage: 91.50%
#
#
# Number of samples: 93940
# Estimated value of Pi is 3.1360017032148177
# Absolute error is 0.0055909503749753675
# Time taken is 0.2637777328491211 seconds
# RAM usage: 2.60%
# CPU usage: 71.40%
#
#
# Number of samples: 94950
# Estimated value of Pi is 3.144476040021064
# Absolute error is 0.002883386431270729
# Time taken is 0.18990778923034668 seconds
# RAM usage: 2.60%
# CPU usage: 91.70%
#
#
# Number of samples: 95960
# Estimated value of Pi is 3.1410587744893705
# Absolute error is 0.000533879100422574
# Time taken is 0.21146345138549805 seconds
# RAM usage: 2.60%
# CPU usage: 87.90%
#
#
# Number of samples: 96970
# Estimated value of Pi is 3.144931422089306
# Absolute error is 0.0033387684995127564
# Time taken is 0.18913054466247559 seconds
# RAM usage: 2.60%
# CPU usage: 91.70%
#
#
# Number of samples: 97980
# Estimated value of Pi is 3.1406817717901614
# Absolute error is 0.0009108817996317242
# Time taken is 0.19602394104003906 seconds
# RAM usage: 2.60%
# CPU usage: 92.90%
#
#
# Number of samples: 98990
# Estimated value of Pi is 3.134781291039499
# Absolute error is 0.006811362550294131
# Time taken is 0.21943020820617676 seconds
# RAM usage: 2.60%
# CPU usage: 84.70%
#
#
# Number of samples: 100000
# Estimated value of Pi is 3.14036
# Absolute error is 0.0012326535897932978
# Time taken is 0.1919257640838623 seconds
# RAM usage: 2.60%
# CPU usage: 91.60%

# %%
import dask
from dask.distributed import Client, as_completed
import random
import math
import time
import matplotlib.pyplot as plt
import psutil

# Function to perform Monte Carlo simulation to estimate Pi
def monte_carlo_simulation(num_samples):
    def is_point_inside_unit_circle(_):
        x, y = random.random(), random.random()
        return x*x + y*y <= 1
    
    counts = [is_point_inside_unit_circle(_) for _ in range(num_samples)]
    count_inside_circle = sum(counts)
    
    pi_estimate = 4 * count_inside_circle / num_samples
    return pi_estimate

if __name__ == "__main__":
    # Dask Client setup
    client = Client()

    sample_sizes = [10,1020,2030,3040,4050,5060,6070,7080,8090,9100,10110,11120,12130,13140,14150,15160,16170,17180,18190,19200,20210,21220,22230,23240,24250,25260,26270,27280,28290,29300,30310,31320,32330,33340,34350,35360,36370,37380,38390,39400,40410,41420,42430,43440,44450,45460,46470,47480,48490,49500,50510,51520,52530,53540,54550,55560,56570,57580,58590,59600,60610,61620,62630,63640,64650,65660,66670,67680,68690,69700,70710,71720,72730,73740,74750,75760,76770,77780,78790,79800,80810,81820,82830,83840,84850,85860,86870,87880,88890,89900,90910,91920,92930,93940,94950,95960,96970,97980,98990,100000]
    futures = []
    for num_samples in sample_sizes:
        # Scatter the function and arguments to the workers
        future = client.submit(monte_carlo_simulation, num_samples)
        futures.append(future)

    pi_estimates = []
    absolute_errors = []
    durations = []
    ram_usage = []
    cpu_usage = []

    start_time = time.time()
    print("========DASK========")
    # Retrieve results as they complete
    for i, future in enumerate(as_completed(futures)):
        result = future.result()
        pi_estimates.append(result)

        # Calculate absolute error
        absolute_error = abs(result - math.pi)
        absolute_errors.append(absolute_error)

        # Calculate duration
        end_time = time.time()
        duration = end_time - start_time
        durations.append(duration)

        # Retrieve system's RAM and CPU usage using psutil
        ram_percent = psutil.virtual_memory().percent
        cpu_percent = psutil.cpu_percent()

        ram_usage.append(ram_percent)
        cpu_usage.append(cpu_percent)

        # Print the result, the accuracy, and the time taken
        print(f"Number of samples: {sample_sizes[i]}")
        print(f"Estimated value of Pi is {result}")
        print(f"Absolute error is {absolute_error}")
        print(f"Time taken is {duration} seconds")
        print(f"RAM usage: {ram_percent:.2f}%")
        print(f"CPU usage: {cpu_percent:.2f}%")
        print("\n")

    # Close the Dask client
    client.close()

    # Plotting results
    plt.figure(figsize=(18, 12))

    # Plot 1: Estimated Pi vs Sample Size
    plt.subplot(2, 2, 1)
    plt.plot(sample_sizes, pi_estimates, marker='o', linestyle='-', color='b', label='Estimated Pi')
    plt.axhline(y=math.pi, color='r', linestyle='--', label='True Pi')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Estimated Pi')
    plt.title('Estimated Pi vs Sample Size')
    plt.legend()

    # Plot 2: Absolute Error vs Sample Size
    plt.subplot(2, 2, 2)
    plt.plot(sample_sizes, absolute_errors, marker='o', linestyle='-', color='g', label='Absolute Error')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Absolute Error')
    plt.title('Absolute Error vs Sample Size')
    plt.legend()

    # Plot 3: Time Taken vs Sample Size
    plt.subplot(2, 2, 3)
    plt.plot(sample_sizes, durations, marker='o', linestyle='-', color='m', label='Time Taken (seconds)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Time Taken (seconds)')
    plt.title('Time Taken vs Sample Size')
    plt.legend()

    # Plot 4: Resource Usage
    plt.subplot(2, 2, 4)
    plt.plot(sample_sizes, ram_usage, marker='o', linestyle='-', color='b', label='RAM Usage (%)')
    plt.plot(sample_sizes, cpu_usage, marker='o', linestyle='-', color='g', label='CPU Usage (%)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Resource Usage (%)')
    plt.title('Resource Usage vs Sample Size')
    plt.legend()

    # Adjust layout and display the plots
    plt.tight_layout()
    plt.show()
# Out:
# ========DASK========
# Number of samples: 10
# Estimated value of Pi is 4.0
# Absolute error is 0.8584073464102069
# Time taken is 0.0282442569732666 seconds
# RAM usage: 2.50%
# CPU usage: 9.80%
#
#
# Number of samples: 1020
# Estimated value of Pi is 3.1921568627450982
# Absolute error is 0.05056420915530513
# Time taken is 0.05510830879211426 seconds
# RAM usage: 2.50%
# CPU usage: 38.10%
#
#
# Number of samples: 2030
# Estimated value of Pi is 3.1448275862068966
# Absolute error is 0.003234932617103503
# Time taken is 0.07839131355285645 seconds
# RAM usage: 2.50%
# CPU usage: 37.80%
#
#
# Number of samples: 3040
# Estimated value of Pi is 3.094736842105263
# Absolute error is 0.04685581148453011
# Time taken is 0.12221789360046387 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 4050
# Estimated value of Pi is 3.1664197530864198
# Absolute error is 0.024827099496626648
# Time taken is 0.13069510459899902 seconds
# RAM usage: 2.50%
# CPU usage: 30.80%
#
#
# Number of samples: 5060
# Estimated value of Pi is 3.1272727272727274
# Absolute error is 0.01431992631706569
# Time taken is 0.14648795127868652 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 6070
# Estimated value of Pi is 3.142009884678748
# Absolute error is 0.00041723108895475036
# Time taken is 0.17216038703918457 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 7080
# Estimated value of Pi is 3.1429378531073446
# Absolute error is 0.0013451995175515208
# Time taken is 0.2025165557861328 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 8090
# Estimated value of Pi is 3.1213844252163163
# Absolute error is 0.0202082283734768
# Time taken is 0.23770666122436523 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 9100
# Estimated value of Pi is 3.0939663699307616
# Absolute error is 0.04762628365903154
# Time taken is 0.2549095153808594 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 10110
# Estimated value of Pi is 3.1626373626373625
# Absolute error is 0.021044709047569388
# Time taken is 0.2798166275024414 seconds
# RAM usage: 2.50%
# CPU usage: 32.50%
#
#
# Number of samples: 11120
# Estimated value of Pi is 3.1449640287769784
# Absolute error is 0.0033713751871853326
# Time taken is 0.3254826068878174 seconds
# RAM usage: 2.50%
# CPU usage: 24.30%
#
#
# Number of samples: 12130
# Estimated value of Pi is 3.1229551451187336
# Absolute error is 0.018637508471059494
# Time taken is 0.33754754066467285 seconds
# RAM usage: 2.50%
# CPU usage: 26.30%
#
#
# Number of samples: 13140
# Estimated value of Pi is 3.1195383347073373
# Absolute error is 0.022054318882455792
# Time taken is 0.36638712882995605 seconds
# RAM usage: 2.50%
# CPU usage: 17.00%
#
#
# Number of samples: 14150
# Estimated value of Pi is 3.1264260768335275
# Absolute error is 0.015166576756265648
# Time taken is 0.3700590133666992 seconds
# RAM usage: 2.50%
# CPU usage: 16.70%
#
#
# Number of samples: 15160
# Estimated value of Pi is 3.1509893455098936
# Absolute error is 0.009396691920100508
# Time taken is 0.37212395668029785 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 16170
# Estimated value of Pi is 3.138867509620671
# Absolute error is 0.002725143969122268
# Time taken is 0.3738696575164795 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 17180
# Estimated value of Pi is 3.1490778227620333
# Absolute error is 0.00748516917224018
# Time taken is 0.37534475326538086 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 18190
# Estimated value of Pi is 3.141766784452297
# Absolute error is 0.0001741308625038407
# Time taken is 0.3770923614501953 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 19200
# Estimated value of Pi is 3.1206333498268184
# Absolute error is 0.020959303762974724
# Time taken is 0.3786590099334717 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 20210
# Estimated value of Pi is 3.133125
# Absolute error is 0.008467653589792956
# Time taken is 0.3803398609161377 seconds
# RAM usage: 2.50%
# CPU usage: 25.00%
#
#
# Number of samples: 21220
# Estimated value of Pi is 3.1713048855906
# Absolute error is 0.02971223200080697
# Time taken is 0.3818972110748291 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 22230
# Estimated value of Pi is 3.1289349670122526
# Absolute error is 0.012657686577540517
# Time taken is 0.38332605361938477 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 23240
# Estimated value of Pi is 3.1334602207841646
# Absolute error is 0.008132432805628476
# Time taken is 0.38483214378356934 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 24250
# Estimated value of Pi is 3.139759036144578
# Absolute error is 0.00183361744521493
# Time taken is 0.3864450454711914 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 25260
# Estimated value of Pi is 3.1459879816189464
# Absolute error is 0.0043953280291533225
# Time taken is 0.38813304901123047 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 26270
# Estimated value of Pi is 3.138766083800726
# Absolute error is 0.002826569789067257
# Time taken is 0.389664888381958 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 27280
# Estimated value of Pi is 3.1424682957005876
# Absolute error is 0.0008756421107944945
# Time taken is 0.3910956382751465 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 28290
# Estimated value of Pi is 3.1471100554235947
# Absolute error is 0.005517401833801561
# Time taken is 0.39273571968078613 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 29300
# Estimated value of Pi is 3.1480938416422286
# Absolute error is 0.0065011880524354915
# Time taken is 0.39434003829956055 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 30310
# Estimated value of Pi is 3.142885424399901
# Absolute error is 0.0012927708101080349
# Time taken is 0.39586877822875977 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 31320
# Estimated value of Pi is 3.1506259097525473
# Absolute error is 0.009033256162754189
# Time taken is 0.3983340263366699 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 32330
# Estimated value of Pi is 3.137379525918208
# Absolute error is 0.004213127671585326
# Time taken is 0.3998720645904541 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 33340
# Estimated value of Pi is 3.152490421455939
# Absolute error is 0.010897767866145713
# Time taken is 0.40147876739501953 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 34350
# Estimated value of Pi is 3.150678733031674
# Absolute error is 0.009086079441881001
# Time taken is 0.40300917625427246 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 35360
# Estimated value of Pi is 3.1363298969072164
# Absolute error is 0.005262756682576697
# Time taken is 0.4053666591644287 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 36370
# Estimated value of Pi is 3.1355631399317407
# Absolute error is 0.006029513658052377
# Time taken is 0.40714406967163086 seconds
# RAM usage: 2.50%
# CPU usage: 25.00%
#
#
# Number of samples: 37380
# Estimated value of Pi is 3.145229584822656
# Absolute error is 0.0036369312328630166
# Time taken is 0.40875697135925293 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 38390
# Estimated value of Pi is 3.1248950209958006
# Absolute error is 0.016697632593992484
# Time taken is 0.4102163314819336 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 39400
# Estimated value of Pi is 3.1295880149812736
# Absolute error is 0.012004638608519524
# Time taken is 0.4116499423980713 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 40410
# Estimated value of Pi is 3.1336040609137057
# Absolute error is 0.007988592676087425
# Time taken is 0.41323375701904297 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 41420
# Estimated value of Pi is 3.1361979752530935
# Absolute error is 0.005394678336699599
# Time taken is 0.41489267349243164 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 42430
# Estimated value of Pi is 3.154069511658601
# Absolute error is 0.012476858068807939
# Time taken is 0.41644859313964844 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 43440
# Estimated value of Pi is 3.145059218667138
# Absolute error is 0.0034665650773448853
# Time taken is 0.4179196357727051 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 44450
# Estimated value of Pi is 3.139740820734341
# Absolute error is 0.0018518328554519847
# Time taken is 0.4246947765350342 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 45460
# Estimated value of Pi is 3.1408981168517625
# Absolute error is 0.00069453673803066
# Time taken is 0.42668843269348145 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 46470
# Estimated value of Pi is 3.151260900306387
# Absolute error is 0.009668246716593831
# Time taken is 0.4283480644226074 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 47480
# Estimated value of Pi is 3.1450828491499894
# Absolute error is 0.003490195560196252
# Time taken is 0.430004358291626 seconds
# RAM usage: 2.50%
# CPU usage: 25.00%
#
#
# Number of samples: 48490
# Estimated value of Pi is 3.1343723673125528
# Absolute error is 0.007220286277240362
# Time taken is 0.4314432144165039 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 49500
# Estimated value of Pi is 3.1418436791090945
# Absolute error is 0.00025102551930134
# Time taken is 0.4331018924713135 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 50510
# Estimated value of Pi is 3.142633517495396
# Absolute error is 0.0010408639056027624
# Time taken is 0.4346163272857666 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 51520
# Estimated value of Pi is 3.1251552795031055
# Absolute error is 0.01643737408668766
# Time taken is 0.4361600875854492 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 52530
# Estimated value of Pi is 3.135919191919192
# Absolute error is 0.005673461670601121
# Time taken is 0.4378073215484619 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 53540
# Estimated value of Pi is 3.130045829514207
# Absolute error is 0.011546824075586049
# Time taken is 0.43932342529296875 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 54550
# Estimated value of Pi is 3.1539783339559206
# Absolute error is 0.012385680366127527
# Time taken is 0.440875768661499 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 55560
# Estimated value of Pi is 3.148193367431117
# Absolute error is 0.006600713841323991
# Time taken is 0.4423668384552002 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 56570
# Estimated value of Pi is 3.140526628390418
# Absolute error is 0.0010660251993752645
# Time taken is 0.44393396377563477 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 57580
# Estimated value of Pi is 3.1550776583034645
# Absolute error is 0.013485004713671422
# Time taken is 0.4455122947692871 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 58590
# Estimated value of Pi is 3.13496644295302
# Absolute error is 0.0066262106367731555
# Time taken is 0.44708991050720215 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 59600
# Estimated value of Pi is 3.153093470397868
# Absolute error is 0.011500816808074799
# Time taken is 0.45091795921325684 seconds
# RAM usage: 2.50%
# CPU usage: 14.30%
#
#
# Number of samples: 60610
# Estimated value of Pi is 3.1465732561681388
# Absolute error is 0.00498060257834565
# Time taken is 0.45247316360473633 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 61620
# Estimated value of Pi is 3.1483848558527265
# Absolute error is 0.006792202262933422
# Time taken is 0.4539973735809326 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 62630
# Estimated value of Pi is 3.1333123821495916
# Absolute error is 0.008280271440201492
# Time taken is 0.4554107189178467 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 63640
# Estimated value of Pi is 3.139453935813508
# Absolute error is 0.0021387177762850484
# Time taken is 0.45708465576171875 seconds
# RAM usage: 2.50%
# CPU usage: 25.00%
#
#
# Number of samples: 64650
# Estimated value of Pi is 3.148328464784161
# Absolute error is 0.006735811194368058
# Time taken is 0.45856356620788574 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 65660
# Estimated value of Pi is 3.155277332945116
# Absolute error is 0.013684679355322693
# Time taken is 0.4600398540496826 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 66670
# Estimated value of Pi is 3.1507683215130022
# Absolute error is 0.009175667923209119
# Time taken is 0.46147847175598145 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 67680
# Estimated value of Pi is 3.1305457861143675
# Absolute error is 0.011046867475425604
# Time taken is 0.4629037380218506 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 68690
# Estimated value of Pi is 3.1467285382830625
# Absolute error is 0.005135884693269421
# Time taken is 0.46440768241882324 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 69700
# Estimated value of Pi is 3.1464562410329986
# Absolute error is 0.004863587443205475
# Time taken is 0.46614956855773926 seconds
# RAM usage: 2.50%
# CPU usage: 25.00%
#
#
# Number of samples: 70710
# Estimated value of Pi is 3.1399430028498574
# Absolute error is 0.0016496507399357263
# Time taken is 0.4677422046661377 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 71720
# Estimated value of Pi is 3.133492366412214
# Absolute error is 0.008100287177579268
# Time taken is 0.4693613052368164 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 72730
# Estimated value of Pi is 3.136963210702341
# Absolute error is 0.00462944288745204
# Time taken is 0.47097182273864746 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 73740
# Estimated value of Pi is 3.1442907512883105
# Absolute error is 0.0026980976985173655
# Time taken is 0.4725174903869629 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 74750
# Estimated value of Pi is 3.1379623264127594
# Absolute error is 0.0036303271770337098
# Time taken is 0.4740474224090576 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 75760
# Estimated value of Pi is 3.1364163484655636
# Absolute error is 0.005176305124229508
# Time taken is 0.4755721092224121 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 76770
# Estimated value of Pi is 3.1471834913552703
# Absolute error is 0.005590837765477197
# Time taken is 0.4771003723144531 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 77780
# Estimated value of Pi is 3.1439178319514913
# Absolute error is 0.0023251783616982102
# Time taken is 0.47852540016174316 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 78790
# Estimated value of Pi is 3.1323733607611213
# Absolute error is 0.009219292828671843
# Time taken is 0.48004984855651855 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 79800
# Estimated value of Pi is 3.1385955649419217
# Absolute error is 0.0029970886478714043
# Time taken is 0.48158979415893555 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 80810
# Estimated value of Pi is 3.1457174638487206
# Absolute error is 0.004124810258927525
# Time taken is 0.48311901092529297 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 81820
# Estimated value of Pi is 3.1500250626566415
# Absolute error is 0.00843240906684839
# Time taken is 0.4846019744873047 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 82830
# Estimated value of Pi is 3.147404492955959
# Absolute error is 0.005811839366165916
# Time taken is 0.4861636161804199 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 83840
# Estimated value of Pi is 3.1450501099975554
# Absolute error is 0.003457456407762294
# Time taken is 0.48760533332824707 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 84850
# Estimated value of Pi is 3.1400607492406345
# Absolute error is 0.0015319043491586193
# Time taken is 0.48917460441589355 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 85860
# Estimated value of Pi is 3.130991186768079
# Absolute error is 0.010601466821714034
# Time taken is 0.4906277656555176 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 86870
# Estimated value of Pi is 3.1411134404845096
# Absolute error is 0.000479213105283538
# Time taken is 0.49221158027648926 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 87880
# Estimated value of Pi is 3.1403246229998847
# Absolute error is 0.001268030589908431
# Time taken is 0.4936821460723877 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 88890
# Estimated value of Pi is 3.15184342284934
# Absolute error is 0.010250769259546821
# Time taken is 0.49509501457214355 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 89900
# Estimated value of Pi is 3.138479670005893
# Absolute error is 0.0031129835839003306
# Time taken is 0.49674034118652344 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 90910
# Estimated value of Pi is 3.1445196484493385
# Absolute error is 0.0029269948595453954
# Time taken is 0.4982609748840332 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 91920
# Estimated value of Pi is 3.1416125838741613
# Absolute error is 1.9930284368196993e-05
# Time taken is 0.4998648166656494 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 92930
# Estimated value of Pi is 3.146477699041267
# Absolute error is 0.004885045451473946
# Time taken is 0.5013353824615479 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 93940
# Estimated value of Pi is 3.139280189749407
# Absolute error is 0.00231246384038597
# Time taken is 0.5027358531951904 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 94950
# Estimated value of Pi is 3.1483976321698304
# Absolute error is 0.0068049785800372575
# Time taken is 0.5041828155517578 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 95960
# Estimated value of Pi is 3.1341166231505655
# Absolute error is 0.007476030439227621
# Time taken is 0.5057084560394287 seconds
# RAM usage: 2.50%
# CPU usage: 33.30%
#
#
# Number of samples: 96970
# Estimated value of Pi is 3.149159037683628
# Absolute error is 0.007566384093834699
# Time taken is 0.507500410079956 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 97980
# Estimated value of Pi is 3.1274292478209404
# Absolute error is 0.014163405768852666
# Time taken is 0.5091876983642578 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 98990
# Estimated value of Pi is 3.14102159031069
# Absolute error is 0.0005710632791031678
# Time taken is 0.5107271671295166 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%
#
#
# Number of samples: 100000
# Estimated value of Pi is 3.14728
# Absolute error is 0.0056873464102067395
# Time taken is 0.5122723579406738 seconds
# RAM usage: 2.50%
# CPU usage: 0.00%

# %%
# pip install ray
import ray
import random
import math
import time
import matplotlib.pyplot as plt
import psutil

# Initialize Ray
ray.init()

# Function to check if a point is inside the unit circle
@ray.remote
def is_point_inside_unit_circle():
    x, y = random.random(), random.random()
    return x*x + y*y <= 1

# Function to perform Monte Carlo simulation to estimate Pi
def monte_carlo_simulation(num_samples):
    # Submit tasks to Ray workers
    futures = [is_point_inside_unit_circle.remote() for _ in range(num_samples)]
    
    # Count the number of points inside the circle
    count_inside_circle = sum(ray.get(futures))
    
    # Estimate Pi
    pi_estimate = 4 * count_inside_circle / num_samples
    return pi_estimate

if __name__ == "__main__":
    sample_sizes = [10,1020,2030,3040,4050,5060,6070,7080,8090,9100,10110,11120,12130,13140,14150,15160,16170,17180,18190,19200,20210,21220,22230,23240,24250,25260,26270,27280,28290,29300,30310,31320,32330,33340,34350,35360,36370,37380,38390,39400,40410,41420,42430,43440,44450,45460,46470,47480,48490,49500,50510,51520,52530,53540,54550,55560,56570,57580,58590,59600,60610,61620,62630,63640,64650,65660,66670,67680,68690,69700,70710,71720,72730,73740,74750,75760,76770,77780,78790,79800,80810,81820,82830,83840,84850,85860,86870,87880,88890,89900,90910,91920,92930,93940,94950,95960,96970,97980,98990,100000]

    pi_estimates = []
    absolute_errors = []
    durations = []
    ram_usage = []
    cpu_usage = []

    start_time = time.time()
    print("========RAY========")
    # Perform Monte Carlo simulation for different sample sizes
    for num_samples in sample_sizes:
        # Execute Monte Carlo simulation using Ray
        result = monte_carlo_simulation(num_samples)
        pi_estimates.append(result)

        # Calculate absolute error
        absolute_error = abs(result - math.pi)
        absolute_errors.append(absolute_error)

        # Calculate duration
        end_time = time.time()
        duration = end_time - start_time
        durations.append(duration)

        # Retrieve system's RAM and CPU usage using psutil
        ram_percent = psutil.virtual_memory().percent
        cpu_percent = psutil.cpu_percent()

        ram_usage.append(ram_percent)
        cpu_usage.append(cpu_percent)

        # Print the result, the accuracy, and the time taken
        print(f"Number of samples: {num_samples}")
        print(f"Estimated value of Pi is {result}")
        print(f"Absolute error is {absolute_error}")
        print(f"Time taken is {duration} seconds")
        print(f"RAM usage: {ram_percent:.2f}%")
        print(f"CPU usage: {cpu_percent:.2f}%")
        print("\n")

    # Shutdown Ray
    ray.shutdown()

    # Plotting results
    plt.figure(figsize=(18, 12))

    # Plot 1: Estimated Pi vs Sample Size
    plt.subplot(2, 2, 1)
    plt.plot(sample_sizes, pi_estimates, marker='o', linestyle='-', color='b', label='Estimated Pi')
    plt.axhline(y=math.pi, color='r', linestyle='--', label='True Pi')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Estimated Pi')
    plt.title('Estimated Pi vs Sample Size')
    plt.legend()

    # Plot 2: Absolute Error vs Sample Size
    plt.subplot(2, 2, 2)
    plt.plot(sample_sizes, absolute_errors, marker='o', linestyle='-', color='g', label='Absolute Error')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Absolute Error')
    plt.title('Absolute Error vs Sample Size')
    plt.legend()

    # Plot 3: Time Taken vs Sample Size
    plt.subplot(2, 2, 3)
    plt.plot(sample_sizes, durations, marker='o', linestyle='-', color='m', label='Time Taken (seconds)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Time Taken (seconds)')
    plt.title('Time Taken vs Sample Size')
    plt.legend()

    # Plot 4: Resource Usage
    plt.subplot(2, 2, 4)
    plt.plot(sample_sizes, ram_usage, marker='o', linestyle='-', color='b', label='RAM Usage (%)')
    plt.plot(sample_sizes, cpu_usage, marker='o', linestyle='-', color='g', label='CPU Usage (%)')
    plt.xscale('log')
    plt.xlabel('Number of Samples')
    plt.ylabel('Resource Usage (%)')
    plt.title('Resource Usage vs Sample Size')
    plt.legend()

    # Adjust layout and display the plots
    plt.tight_layout()
    plt.show()
# Out:
# 2024-07-19 15:25:08,185	WARNING services.py:2010 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2024-07-19 15:25:08,326	INFO worker.py:1788 -- Started a local Ray instance.
# ========RAY========
# Number of samples: 10
# Estimated value of Pi is 4.0
# Absolute error is 0.8584073464102069
# Time taken is 0.3891282081604004 seconds
# RAM usage: 3.30%
# CPU usage: 24.40%
#
#
# Number of samples: 1020
# Estimated value of Pi is 3.196078431372549
# Absolute error is 0.054485777782756095
# Time taken is 0.5969822406768799 seconds
# RAM usage: 3.40%
# CPU usage: 65.40%
#
#
# Number of samples: 2030
# Estimated value of Pi is 3.1921182266009853
# Absolute error is 0.050525573011192204
# Time taken is 0.8393585681915283 seconds
# RAM usage: 3.40%
# CPU usage: 52.40%
#
#
# Number of samples: 3040
# Estimated value of Pi is 3.143421052631579
# Absolute error is 0.0018283990417859997
# Time taken is 1.2469525337219238 seconds
# RAM usage: 3.50%
# CPU usage: 61.50%
#
#
# Number of samples: 4050
# Estimated value of Pi is 3.168395061728395
# Absolute error is 0.02680240813860202
# Time taken is 1.7405426502227783 seconds
# RAM usage: 3.50%
# CPU usage: 56.70%
#
#
# Number of samples: 5060
# Estimated value of Pi is 3.1383399209486167
# Absolute error is 0.0032527326411764257
# Time taken is 2.4214460849761963 seconds
# RAM usage: 3.60%
# CPU usage: 61.00%
#
#
# Number of samples: 6070
# Estimated value of Pi is 3.1479406919275124
# Absolute error is 0.006348038337719242
# Time taken is 3.1664950847625732 seconds
# RAM usage: 3.70%
# CPU usage: 60.30%
#
#
# Number of samples: 7080
# Estimated value of Pi is 3.16045197740113
# Absolute error is 0.018859323811336814
# Time taken is 4.060868501663208 seconds
# RAM usage: 3.70%
# CPU usage: 54.50%
#
#
# Number of samples: 8090
# Estimated value of Pi is 3.130778739184178
# Absolute error is 0.010813914405614966
# Time taken is 5.120816469192505 seconds
# RAM usage: 3.70%
# CPU usage: 57.30%
#
#
# Number of samples: 9100
# Estimated value of Pi is 3.157802197802198
# Absolute error is 0.016209544212404836
# Time taken is 6.484205961227417 seconds
# RAM usage: 3.70%
# CPU usage: 49.30%
#
#
# Number of samples: 10110
# Estimated value of Pi is 3.1212660731948567
# Absolute error is 0.0203265803949364
# Time taken is 7.8281238079071045 seconds
# RAM usage: 3.70%
# CPU usage: 53.40%
#
#
# Number of samples: 11120
# Estimated value of Pi is 3.1420863309352516
# Absolute error is 0.0004936773454584653
# Time taken is 9.410179615020752 seconds
# RAM usage: 3.80%
# CPU usage: 55.20%
#
#
# Number of samples: 12130
# Estimated value of Pi is 3.1370156636438584
# Absolute error is 0.004576989945934695
# Time taken is 11.05878472328186 seconds
# RAM usage: 3.80%
# CPU usage: 51.60%
#
#
# Number of samples: 13140
# Estimated value of Pi is 3.1333333333333333
# Absolute error is 0.008259320256459812
# Time taken is 12.918020009994507 seconds
# RAM usage: 3.80%
# CPU usage: 53.80%
#
#
# Number of samples: 14150
# Estimated value of Pi is 3.1270671378091874
# Absolute error is 0.01452551578060568
# Time taken is 14.905723333358765 seconds
# RAM usage: 3.80%
# CPU usage: 53.90%
#
#
# Number of samples: 15160
# Estimated value of Pi is 3.127440633245383
# Absolute error is 0.014152020344410321
# Time taken is 17.15008306503296 seconds
# RAM usage: 3.80%
# CPU usage: 51.30%
#
#
# Number of samples: 16170
# Estimated value of Pi is 3.1470624613481757
# Absolute error is 0.005469807758382572
# Time taken is 19.515161752700806 seconds
# RAM usage: 3.80%
# CPU usage: 51.00%
#
#
# Number of samples: 17180
# Estimated value of Pi is 3.1462165308498253
# Absolute error is 0.0046238772600322164
# Time taken is 22.026585578918457 seconds
# RAM usage: 3.80%
# CPU usage: 51.90%
#
#
# Number of samples: 18190
# Estimated value of Pi is 3.149642660802639
# Absolute error is 0.008050007212845767
# Time taken is 24.656458854675293 seconds
# RAM usage: 3.80%
# CPU usage: 49.70%
#
#
# Number of samples: 19200
# Estimated value of Pi is 3.1510416666666665
# Absolute error is 0.009449013076873403
# Time taken is 27.557254552841187 seconds
# RAM usage: 3.80%
# CPU usage: 49.90%
#
#
# Number of samples: 20210
# Estimated value of Pi is 3.1224146462147453
# Absolute error is 0.019178007375047823
# Time taken is 30.538251876831055 seconds
# RAM usage: 3.90%
# CPU usage: 52.90%
#
#
# Number of samples: 21220
# Estimated value of Pi is 3.1475966069745525
# Absolute error is 0.006003953384759342
# Time taken is 33.81417489051819 seconds
# RAM usage: 3.80%
# CPU usage: 49.50%
#
#
# Number of samples: 22230
# Estimated value of Pi is 3.1316239316239316
# Absolute error is 0.009968721965861516
# Time taken is 37.14361071586609 seconds
# RAM usage: 3.80%
# CPU usage: 50.50%
#
#
# Number of samples: 23240
# Estimated value of Pi is 3.131497418244406
# Absolute error is 0.010095235345386921
# Time taken is 40.641637325286865 seconds
# RAM usage: 3.90%
# CPU usage: 49.70%
#
#
# Number of samples: 24250
# Estimated value of Pi is 3.146556701030928
# Absolute error is 0.004964047441134767
# Time taken is 44.24281096458435 seconds
# RAM usage: 3.90%
# CPU usage: 50.50%
#
#
# Number of samples: 25260
# Estimated value of Pi is 3.1205067300079175
# Absolute error is 0.021085923581875665
# Time taken is 48.209683418273926 seconds
# RAM usage: 3.90%
# CPU usage: 47.80%
#
#
# Number of samples: 26270
# Estimated value of Pi is 3.1258469737342978
# Absolute error is 0.015745679855495354
# Time taken is 52.290562868118286 seconds
# RAM usage: 3.90%
# CPU usage: 49.60%
#
#
# Number of samples: 27280
# Estimated value of Pi is 3.1369501466275658
# Absolute error is 0.004642506962227344
# Time taken is 56.46976971626282 seconds
# RAM usage: 3.90%
# CPU usage: 49.70%
#
#
# Number of samples: 28290
# Estimated value of Pi is 3.134252386002121
# Absolute error is 0.007340267587672145
# Time taken is 60.95504403114319 seconds
# RAM usage: 3.90%
# CPU usage: 48.20%
#
#
# Number of samples: 29300
# Estimated value of Pi is 3.1419795221843003
# Absolute error is 0.0003868685945072059
# Time taken is 65.35190773010254 seconds
# RAM usage: 4.00%
# CPU usage: 49.80%
#
#
# Number of samples: 30310
# Estimated value of Pi is 3.1516991092048827
# Absolute error is 0.010106455615089605
# Time taken is 70.11324572563171 seconds
# RAM usage: 4.00%
# CPU usage: 48.80%
#
#
# Number of samples: 31320
# Estimated value of Pi is 3.141890166028097
# Absolute error is 0.000297512438304004
# Time taken is 74.68187665939331 seconds
# RAM usage: 4.00%
# CPU usage: 51.20%
#
#
# Number of samples: 32330
# Estimated value of Pi is 3.1449427776059387
# Absolute error is 0.0033501240161455392
# Time taken is 79.58387565612793 seconds
# RAM usage: 4.00%
# CPU usage: 50.10%
#
#
# Number of samples: 33340
# Estimated value of Pi is 3.1358128374325136
# Absolute error is 0.005779816157279516
# Time taken is 84.57354784011841 seconds
# RAM usage: 4.00%
# CPU usage: 50.00%
#
#
# Number of samples: 34350
# Estimated value of Pi is 3.125938864628821
# Absolute error is 0.015653788960972026
# Time taken is 89.74002122879028 seconds
# RAM usage: 4.00%
# CPU usage: 50.40%
#
#
# (is_point_inside_unit_circle pid=20642) :t
# (is_point_inside_unit_circle pid=20642) ask_name:is_point_inside_unit_circle
# Number of samples: 35360
# Estimated value of Pi is 3.137443438914027
# Absolute error is 0.004149214675766011
# Time taken is 94.9691526889801 seconds
# RAM usage: 4.00%
# CPU usage: 50.40%
#
#
# Number of samples: 36370
# Estimated value of Pi is 3.154797910365686
# Absolute error is 0.013205256775892682
# Time taken is 100.42411994934082 seconds
# RAM usage: 4.00%
# CPU usage: 50.70%
#
#
# (is_point_inside_unit_circle pid=20637) :task_
# (is_point_inside_unit_circle pid=20637) name:is_point_inside_unit_circle
# Number of samples: 37380
# Estimated value of Pi is 3.1418940609951846
# Absolute error is 0.00030140740539152944
# Time taken is 105.9552731513977 seconds
# RAM usage: 4.10%
# CPU usage: 51.20%
#
#
# Number of samples: 38390
# Estimated value of Pi is 3.1320656420942954
# Absolute error is 0.009527011495497728
# Time taken is 111.97127866744995 seconds
# RAM usage: 4.10%
# CPU usage: 48.40%
#
#
# Number of samples: 39400
# Estimated value of Pi is 3.140812182741117
# Absolute error is 0.0007804708486762735
# Time taken is 117.79850602149963 seconds
# RAM usage: 4.10%
# CPU usage: 52.20%
#
#
# (is_point_inside_un pid=20637) it_circle
# Number of samples: 40410
# Estimated value of Pi is 3.143776292996783
# Absolute error is 0.0021836394069900678
# Time taken is 123.70723056793213 seconds
# RAM usage: 4.10%
# CPU usage: 51.70%
#
#
# Number of samples: 41420
# Estimated value of Pi is 3.131723804925157
# Absolute error is 0.009868848664636332
# Time taken is 130.00913953781128 seconds
# RAM usage: 4.10%
# CPU usage: 49.60%
#
#
# Number of samples: 42430
# Estimated value of Pi is 3.1378741456516615
# Absolute error is 0.0037185079381316655
# Time taken is 136.37332916259766 seconds
# RAM usage: 4.10%
# CPU usage: 50.10%
#
#
# Number of samples: 43440
# Estimated value of Pi is 3.1593922651933704
# Absolute error is 0.017799611603577237
# Time taken is 142.69111442565918 seconds
# RAM usage: 4.10%
# CPU usage: 51.30%
#
#
# Number of samples: 44450
# Estimated value of Pi is 3.1518560179977504
# Absolute error is 0.010263364407957276
# Time taken is 149.20969104766846 seconds
# RAM usage: 4.10%
# CPU usage: 51.60%
#
#
# Number of samples: 45460
# Estimated value of Pi is 3.1583809942806864
# Absolute error is 0.0167883406908933
# Time taken is 156.04235339164734 seconds
# RAM usage: 4.10%
# CPU usage: 50.40%
#
#
# Number of samples: 46470
# Estimated value of Pi is 3.1395739186571983
# Absolute error is 0.0020187349325948567
# Time taken is 162.8402876853943 seconds
# RAM usage: 4.10%
# CPU usage: 51.90%
#
#
# Number of samples: 47480
# Estimated value of Pi is 3.1457455770850884
# Absolute error is 0.00415292349529528
# Time taken is 169.96226167678833 seconds
# RAM usage: 4.10%
# CPU usage: 50.80%
#
#
# Number of samples: 48490
# Estimated value of Pi is 3.1330996081666322
# Absolute error is 0.008493045423160872
# Time taken is 177.27083945274353 seconds
# RAM usage: 4.10%
# CPU usage: 50.60%
#
#
# Number of samples: 49500
# Estimated value of Pi is 3.143111111111111
# Absolute error is 0.0015184575213180729
# Time taken is 184.72652435302734 seconds
# RAM usage: 4.10%
# CPU usage: 50.30%
#
#
# Number of samples: 50510
# Estimated value of Pi is 3.1364086319540685
# Absolute error is 0.005184021635724623
# Time taken is 192.4714105129242 seconds
# RAM usage: 4.10%
# CPU usage: 49.50%
#
#
# Number of samples: 51520
# Estimated value of Pi is 3.154891304347826
# Absolute error is 0.013298650758033048
# Time taken is 200.33764934539795 seconds
# RAM usage: 4.10%
# CPU usage: 50.00%
#
#
# Number of samples: 52530
# Estimated value of Pi is 3.1292594707786026
# Absolute error is 0.012333182811190557
# Time taken is 208.44801259040833 seconds
# RAM usage: 4.10%
# CPU usage: 49.10%
#
#
# Number of samples: 53540
# Estimated value of Pi is 3.137840866641763
# Absolute error is 0.0037517869480301336
# Time taken is 216.56925106048584 seconds
# RAM usage: 4.20%
# CPU usage: 50.60%
#
#
# Number of samples: 54550
# Estimated value of Pi is 3.1451512373968837
# Absolute error is 0.0035585838070906206
# Time taken is 224.97810816764832 seconds
# RAM usage: 4.20%
# CPU usage: 49.90%
#
#
# Number of samples: 55560
# Estimated value of Pi is 3.146436285097192
# Absolute error is 0.004843631507398971
# Time taken is 233.17850518226624 seconds
# RAM usage: 4.10%
# CPU usage: 51.20%
#
#
# Number of samples: 56570
# Estimated value of Pi is 3.129998232278593
# Absolute error is 0.011594421311200254
# Time taken is 242.15884613990784 seconds
# RAM usage: 4.10%
# CPU usage: 48.40%
#
#
# Number of samples: 57580
# Estimated value of Pi is 3.131712400138937
# Absolute error is 0.009880253450856191
# Time taken is 251.09034538269043 seconds
# RAM usage: 4.20%
# CPU usage: 49.70%
#
#
# Number of samples: 58590
# Estimated value of Pi is 3.1466120498378563
# Absolute error is 0.005019396248063135
# Time taken is 259.8847870826721 seconds
# RAM usage: 4.20%
# CPU usage: 50.20%
#
#
# Number of samples: 59600
# Estimated value of Pi is 3.143959731543624
# Absolute error is 0.002367077953830954
# Time taken is 268.95321679115295 seconds
# RAM usage: 4.10%
# CPU usage: 50.20%
#
#
# Number of samples: 60610
# Estimated value of Pi is 3.1511631743936643
# Absolute error is 0.009570520803871219
# Time taken is 278.36355543136597 seconds
# RAM usage: 4.20%
# CPU usage: 49.50%
#
#
# Number of samples: 61620
# Estimated value of Pi is 3.1358649789029536
# Absolute error is 0.005727674686839546
# Time taken is 287.63163208961487 seconds
# RAM usage: 4.10%
# CPU usage: 50.40%
#
#
# Number of samples: 62630
# Estimated value of Pi is 3.1515248283570174
# Absolute error is 0.0099321747672243
# Time taken is 297.00307297706604 seconds
# RAM usage: 4.10%
# CPU usage: 50.50%
#
#
# Number of samples: 63640
# Estimated value of Pi is 3.1250157133878065
# Absolute error is 0.016576940201986634
# Time taken is 306.9757614135742 seconds
# RAM usage: 4.10%
# CPU usage: 48.90%
#
#
# Number of samples: 64650
# Estimated value of Pi is 3.137200309358082
# Absolute error is 0.004392344231711309
# Time taken is 316.6896142959595 seconds
# RAM usage: 4.10%
# CPU usage: 50.10%
#
#
# Number of samples: 65660
# Estimated value of Pi is 3.1480353335363995
# Absolute error is 0.006442679946606411
# Time taken is 326.43712091445923 seconds
# RAM usage: 4.10%
# CPU usage: 51.60%
#
#
# Number of samples: 66670
# Estimated value of Pi is 3.142222888855557
# Absolute error is 0.0006302352657638899
# Time taken is 336.52853322029114 seconds
# RAM usage: 4.20%
# CPU usage: 51.00%
#
#
# Number of samples: 67680
# Estimated value of Pi is 3.1416666666666666
# Absolute error is 7.401307687349146e-05
# Time taken is 346.64532232284546 seconds
# RAM usage: 4.10%
# CPU usage: 51.40%
#
#
# (is_point_inside_unit_circle pid=20639) :t
# (is_point_inside_unit_circle pid=20639) ask_name:is_point_inside_unit_circle
# Number of samples: 68690
# Estimated value of Pi is 3.146134808560198
# Absolute error is 0.004542154970404777
# Time taken is 357.27709102630615 seconds
# RAM usage: 4.20%
# CPU usage: 49.90%
#
#
# Number of samples: 69700
# Estimated value of Pi is 3.142266857962697
# Absolute error is 0.000674204372903997
# Time taken is 367.67518377304077 seconds
# RAM usage: 4.20%
# CPU usage: 51.50%
#
#
# Number of samples: 70710
# Estimated value of Pi is 3.1430349314099844
# Absolute error is 0.00144227782019124
# Time taken is 378.19368386268616 seconds
# RAM usage: 4.20%
# CPU usage: 51.50%
#
#
# Number of samples: 71720
# Estimated value of Pi is 3.13680981595092
# Absolute error is 0.004782837638872994
# Time taken is 389.1684489250183 seconds
# RAM usage: 4.20%
# CPU usage: 50.70%
#
#
# Number of samples: 72730
# Estimated value of Pi is 3.133507493468995
# Absolute error is 0.008085160120798296
# Time taken is 400.1004755496979 seconds
# RAM usage: 4.10%
# CPU usage: 51.20%
#
#
# Number of samples: 73740
# Estimated value of Pi is 3.1362625440737726
# Absolute error is 0.005330109516020531
# Time taken is 411.39097476005554 seconds
# RAM usage: 4.20%
# CPU usage: 50.40%
#
#
# Number of samples: 74750
# Estimated value of Pi is 3.134876254180602
# Absolute error is 0.006716399409190998
# Time taken is 422.760883808136 seconds
# RAM usage: 4.20%
# CPU usage: 51.10%
#
#
# Number of samples: 75760
# Estimated value of Pi is 3.1376979936642027
# Absolute error is 0.00389465992559046
# Time taken is 434.845988035202 seconds
# RAM usage: 4.10%
# CPU usage: 48.40%
#
#
# Number of samples: 76770
# Estimated value of Pi is 3.1402891754591638
# Absolute error is 0.0013034781306293652
# Time taken is 446.815958738327 seconds
# RAM usage: 4.20%
# CPU usage: 50.00%
#
#
# (is_p pid=20638) oint_inside_unit_circle
# Number of samples: 77780
# Estimated value of Pi is 3.1460015428130625
# Absolute error is 0.00440888922326943
# Time taken is 459.2105689048767 seconds
# RAM usage: 4.20%
# CPU usage: 48.80%
#
#
# Number of samples: 78790
# Estimated value of Pi is 3.148267546642975
# Absolute error is 0.006674893053181918
# Time taken is 471.3258125782013 seconds
# RAM usage: 4.20%
# CPU usage: 50.10%
#
#
# Number of samples: 79800
# Estimated value of Pi is 3.1473684210526316
# Absolute error is 0.005775767462838477
# Time taken is 483.58055567741394 seconds
# RAM usage: 4.20%
# CPU usage: 50.50%
#
#
# Number of samples: 80810
# Estimated value of Pi is 3.135354535329786
# Absolute error is 0.006238118260007308
# Time taken is 495.77654123306274 seconds
# RAM usage: 4.20%
# CPU usage: 51.00%
#
#
# (is_point_inside_unit_circl pid=20643) e
# Number of samples: 81820
# Estimated value of Pi is 3.1413835248105597
# Absolute error is 0.0002091287792334029
# Time taken is 508.5294313430786 seconds
# RAM usage: 4.20%
# CPU usage: 49.70%
#
#
# Number of samples: 82830
# Estimated value of Pi is 3.136351563443197
# Absolute error is 0.005241090146596239
# Time taken is 521.5734248161316 seconds
# RAM usage: 4.20%
# CPU usage: 49.30%
#
#
# Number of samples: 83840
# Estimated value of Pi is 3.1416507633587787
# Absolute error is 5.81097689855703e-05
# Time taken is 534.8916251659393 seconds
# RAM usage: 4.20%
# CPU usage: 48.90%
#
#
# Number of samples: 84850
# Estimated value of Pi is 3.139705362404243
# Absolute error is 0.0018872911855503105
# Time taken is 547.7412512302399 seconds
# RAM usage: 4.20%
# CPU usage: 51.10%
#
#
# Number of samples: 85860
# Estimated value of Pi is 3.1394828791055205
# Absolute error is 0.0021097744842726307
# Time taken is 561.0235471725464 seconds
# RAM usage: 4.20%
# CPU usage: 49.90%
#
#
# Number of samples: 86870
# Estimated value of Pi is 3.1444687464026706
# Absolute error is 0.0028760928128774843
# Time taken is 573.9651985168457 seconds
# RAM usage: 4.20%
# CPU usage: 51.60%
#
#
# Number of samples: 87880
# Estimated value of Pi is 3.1472917614929448
# Absolute error is 0.005699107903151646
# Time taken is 587.2289409637451 seconds
# RAM usage: 4.20%
# CPU usage: 50.80%
#
#
# Number of samples: 88890
# Estimated value of Pi is 3.137585780177748
# Absolute error is 0.004006873412045309
# Time taken is 600.7430903911591 seconds
# RAM usage: 4.20%
# CPU usage: 50.80%
#
#
# Number of samples: 89900
# Estimated value of Pi is 3.1437152391546164
# Absolute error is 0.002122585564823254
# Time taken is 614.41339802742 seconds
# RAM usage: 4.20%
# CPU usage: 50.50%
#
#
# Number of samples: 90910
# Estimated value of Pi is 3.1407325926740732
# Absolute error is 0.0008600609157198846
# Time taken is 627.6747534275055 seconds
# RAM usage: 4.20%
# CPU usage: 52.30%
#
#
# Number of samples: 91920
# Estimated value of Pi is 3.1456483899042644
# Absolute error is 0.004055736314471314
# Time taken is 643.4987270832062 seconds
# RAM usage: 4.20%
# CPU usage: 45.10%
#
#
# (is_point_inside_unit_circle pid=20642) :task_n
# (is_point_inside_unit_circle pid=20642) ame:is_point_inside_unit_circle
# Number of samples: 92930
# Estimated value of Pi is 3.1536425266329497
# Absolute error is 0.012049873043156634
# Time taken is 659.4599843025208 seconds
# RAM usage: 4.20%
# CPU usage: 45.60%
#
#
# Number of samples: 93940
# Estimated value of Pi is 3.1521822439855227
# Absolute error is 0.010589590395729598
# Time taken is 673.8903021812439 seconds
# RAM usage: 4.20%
# CPU usage: 50.20%
#
#
# Number of samples: 94950
# Estimated value of Pi is 3.1375250131648236
# Absolute error is 0.004067640424969543
# Time taken is 689.3526449203491 seconds
# RAM usage: 4.20%
# CPU usage: 47.80%
#
#
# Number of samples: 95960
# Estimated value of Pi is 3.1428928720300124
# Absolute error is 0.001300218440219325
# Time taken is 704.5755965709686 seconds
# RAM usage: 4.20%
# CPU usage: 49.30%
#
#
# Number of samples: 96970
# Estimated value of Pi is 3.1396926884603484
# Absolute error is 0.0018999651294446807
# Time taken is 719.8975923061371 seconds
# RAM usage: 4.20%
# CPU usage: 49.10%
#
#
# Number of samples: 97980
# Estimated value of Pi is 3.138068993672178
# Absolute error is 0.003523659917615163
# Time taken is 735.6505572795868 seconds
# RAM usage: 4.20%
# CPU usage: 48.30%
#
#
# Number of samples: 98990
# Estimated value of Pi is 3.137771492069906
# Absolute error is 0.003821161519887095
# Time taken is 751.1543071269989 seconds
# RAM usage: 4.20%
# CPU usage: 49.30%
#
#
# Number of samples: 100000
# Estimated value of Pi is 3.1432
# Absolute error is 0.0016073464102071
# Time taken is 767.0559525489807 seconds
# RAM usage: 4.20%
# CPU usage: 48.70%

# %%
print('over')
# Out:
# over
